# %%
from tensorflow.keras.models import load_model

# %%
model = load_model('D:/FCI/graduation project/smart city/Machine Learning/Road_Crack_Detection_Model_2000.h5')

# %%
import cv2
import numpy as np

# %%
video = cv2.VideoCapture("D:/FCI/graduation project/smart city/Machine Learning/fire and non fire images and videos/non fire video 1.mp4")

# %%
def preprocessing_image(frame):
    if frame is None:
        print("Error: Could not load image")
    frame = cv2.cvtColor(frame, cv2.COLOR_RGB2BGR) #convert
    frame = cv2.resize(frame, (227,227))  # resize
    frame = frame / 255 #scale
    return frame

# %%
X = []
while (video.isOpened()): # while this loop is running, we will extract the frames from the video
    ret, frame = video.read() #ret is a boolean value that indicates whether we are getting frames or not #frame is the variable that stores the frames
    #Grabs, decodes and returns the next video frame.
    if ret==False: # if the video ends, go out of the loop
        print("video ended")
        break
    
    frame = cv2.resize(frame, (1200,700))
    cv2.imshow('Frame',frame)
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
    
    img = preprocessing_image(frame)
    X.append(img)
    
video.release()
cv2.destroyAllWindows()
# Out:
# video ended

# %%
X = np.array(X)

# %%
X.shape
# Out:
# (850, 227, 227, 3)

# %%
y_pred = model.predict(X)
# Out:
# 27/27 [==============================] - 8s 150ms/step

# %%
y_pred = y_pred > 0.5

# %%
y_pred
# Out:
# array([[False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
# ...

# %%
y_pred.shape
# Out:
# (850, 1)

# %%
y_pred = y_pred.reshape(y_pred.shape[0],)

# %%
y_pred
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False,  True, False, False, False, False,
#         True, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
# ...

# %%
count_true = np.count_nonzero(y_pred == True)

# %%
count_true
# Out:
# 82

# %%
#82/850 crack  -> which means not cracked
